# %% [markdown]
# ## Exploration of cumulative return of stocks

# %% [markdown]
# Plot the cumulative returns fot the three stocks in our dataset: IBM, SPY, GOOG.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import QLearner as ql
import pandas as pd
import util as ut

# Pretty display for notebooks
# %matplotlib inline

# %%
stdate =dt.datetime(2016,3,29)
enddate =dt.datetime(2016,11,21) 

dates = pd.date_range(stdate, enddate)
syms=["GOOG"]
prices_all = ut.get_data(syms, dates)  
prices = prices_all["GOOG"]
ut.plot_bollinger_bands(prices,window=15)

plt.show()
